# %% [markdown]
# # Lendo/Tratando dados

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('emotions.csv')

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df.head(30)
# Out:
#     # mean_0_a  mean_1_a  mean_2_a  mean_3_a  mean_4_a  mean_d_0_a  \
# 0        4.620      30.3   -356.00     15.60      26.3      1.0700
# 1       28.800      33.1     32.00     25.80      22.8      6.5500
# 2        8.900      29.4   -416.00     16.70      23.7     79.9000
# 3       14.900      31.6   -143.00     19.80      24.3     -0.5840
# 4       28.300      31.3     45.20     27.30      24.5     34.8000
# 5       31.000      30.9     29.60     28.50      24.0      1.6500
# 6       10.800      21.0     44.70      4.87      28.1      2.1400
# 7       17.800      27.8   -102.00     16.90      26.9     -3.2100
# 8       11.500      29.7     34.90     10.20      26.9    -38.0000
# 9        8.910      29.2   -314.00      6.51      30.9     -1.8800
# 10       5.210      28.4     18.50      3.66      22.6     -0.1190
# 11      13.300      30.4   -149.00     11.80      28.3      3.0300
# 12      30.100      32.7     29.40     28.30      24.3     -6.0500
# ...

# %% [markdown]
# # Treinando modelo

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(df.drop('label',axis=1), 
                                                    df['label'], test_size=0.30)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
dtree = RandomForestClassifier(n_estimators = 200)
dtree.fit(x_train, y_train)
predict = dtree.predict(x_test)

# %%
predict
# Out:
# array(['NEGATIVE', 'POSITIVE', 'NEGATIVE', 'NEUTRAL', 'POSITIVE',
#        'NEGATIVE', 'NEGATIVE', 'POSITIVE', 'NEUTRAL', 'NEGATIVE',
#        'NEGATIVE', 'POSITIVE', 'POSITIVE', 'POSITIVE', 'NEGATIVE',
#        'NEUTRAL', 'NEUTRAL', 'NEUTRAL', 'POSITIVE', 'NEUTRAL', 'POSITIVE',
#        'NEUTRAL', 'NEUTRAL', 'NEUTRAL', 'POSITIVE', 'NEUTRAL', 'NEGATIVE',
#        'NEGATIVE', 'NEUTRAL', 'POSITIVE', 'NEGATIVE', 'POSITIVE',
#        'POSITIVE', 'POSITIVE', 'NEUTRAL', 'NEUTRAL', 'POSITIVE',
#        'POSITIVE', 'NEGATIVE', 'NEGATIVE', 'NEGATIVE', 'NEUTRAL',
#        'NEGATIVE', 'NEUTRAL', 'NEGATIVE', 'POSITIVE', 'POSITIVE',
#        'NEGATIVE', 'NEUTRAL', 'NEGATIVE', 'NEGATIVE', 'NEUTRAL',
#        'NEUTRAL', 'NEUTRAL', 'NEGATIVE', 'POSITIVE', 'NEGATIVE',
#        'NEUTRAL', 'POSITIVE', 'NEUTRAL', 'NEGATIVE', 'POSITIVE',
#        'NEGATIVE', 'NEUTRAL', 'POSITIVE', 'NEGATIVE', 'POSITIVE',
#        'NEGATIVE', 'NEUTRAL', 'NEUTRAL', 'NEUTRAL', 'NEGATIVE',
# ...

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, predict))
# Out:
#               precision    recall  f1-score   support
#
#     NEGATIVE       0.98      1.00      0.99       241
#      NEUTRAL       1.00      0.99      0.99       200
#     POSITIVE       0.98      0.98      0.98       199
#
#     accuracy                           0.99       640
#    macro avg       0.99      0.99      0.99       640
# weighted avg       0.99      0.99      0.99       640

# %%
import pickle
pickle.dump(dtree, open('DEUS VULT.sat', 'wb'))
#modelo = pickle.load(open('DEUS VULT.sat', 'rb'))

# %% [markdown]
# # Teste para Erro

# %%
x_train, x_test, y_train, y_test = train_test_split(df.drop('label',axis=1), 
                                                    df['label'], test_size=0.30)

y_train_forjado = []

for i in range(0, 1492):
    y_train_forjado.append('POSITIVE')

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
dtree = DecisionTreeClassifier()
dtree.fit(x_train, pd.Series(y_train_forjado))
predict = dtree.predict(x_test)

# %%
print(classification_report(y_test, predict))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-568670dd9018> in <module>
# ----> 1 print(classification_report(y_test, predict))
#
# NameError: name 'classification_report' is not defined

# %% [markdown]
# # Gerando um arquivo menor

# %%
dfMenor = pd.read_csv('emotions.csv')

# %%
dfMenor = dfMenor.drop('label', axis = 1)

# %%
dfMenor = dfMenor.iloc[:50, :]

# %%
dfMenor
# Out:
#     # mean_0_a  mean_1_a  mean_2_a  mean_3_a  mean_4_a  mean_d_0_a  \
# 0        4.620      30.3   -356.00    15.600      26.3      1.0700
# 1       28.800      33.1     32.00    25.800      22.8      6.5500
# 2        8.900      29.4   -416.00    16.700      23.7     79.9000
# 3       14.900      31.6   -143.00    19.800      24.3     -0.5840
# 4       28.300      31.3     45.20    27.300      24.5     34.8000
# 5       31.000      30.9     29.60    28.500      24.0      1.6500
# 6       10.800      21.0     44.70     4.870      28.1      2.1400
# 7       17.800      27.8   -102.00    16.900      26.9     -3.2100
# 8       11.500      29.7     34.90    10.200      26.9    -38.0000
# 9        8.910      29.2   -314.00     6.510      30.9     -1.8800
# 10       5.210      28.4     18.50     3.660      22.6     -0.1190
# 11      13.300      30.4   -149.00    11.800      28.3      3.0300
# 12      30.100      32.7     29.40    28.300      24.3     -6.0500
# ...

# %%
dfMenor.to_csv('menor.csv')
